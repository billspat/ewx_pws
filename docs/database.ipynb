# %%
import json
from pprint import pprint
import os

from ewx_pws import weather_stations
from ewx_pws.weather_collector import WeatherCollector

import pandas as pd
from IPython.display import display

# %%
station_config_file = "../test_stations.csv"
collector = WeatherCollector.init_from_station_file(station_config_file)
collector.stations
# Out:
# 2023-09-14 16:00:06,384-25650-DEBUG-instantiating EWX-METER-FO
# 2023-09-14 16:00:06,385-25650-DEBUG-instantiating EWXDAVIS01
# 2023-09-14 16:00:06,386-25650-DEBUG-instantiating EWXSPECTRUM01
# 2023-09-14 16:00:06,386-25650-DEBUG-instantiating EWXONSET01
# 2023-09-14 16:00:06,387-25650-DEBUG-instantiating EWXRAINWISE01
# 2023-09-14 16:00:06,387-25650-DEBUG-instantiating EWXLOCOMOS06
# 2023-09-14 16:00:06,387-25650-DEBUG-instantiating EWX-METER-FO2
# [<ewx_pws.zentra.ZentraStation at 0x1058affa0>,
#  <ewx_pws.davis.DavisStation at 0x1057593a0>,
#  <ewx_pws.spectrum.SpectrumStation at 0x10577daf0>,
#  <ewx_pws.onset.OnsetStation at 0x10577ddc0>,
#  <ewx_pws.rainwise.RainwiseStation at 0x10577d9a0>,
#  <ewx_pws.locomos.LocomosStation at 0x10577da00>,
#  <ewx_pws.zentra.ZentraStation at 0x10577d6d0>]

# %%
from ewx_pws.time_intervals import UTCInterval
interval = UTCInterval.previous_interval(delta_mins = 720)

# %%
raw_records, readings_records = collector.collect_readings(interval)
readings_df = pd.DataFrame(readings_records)
display(readings_df)
# Out:
# 2023-09-14 16:00:10,808-25650-DEBUG-Starting new HTTPS connection (1): zentracloud.com:443
# 2023-09-14 16:00:13,414-25650-DEBUG-https://zentracloud.com:443 "GET /api/v4/get_readings/?device_sn=z6-12564&start_date=2023-09-14+04%3A00%3A00&end_date=2023-09-14+16%3A00%3A00&page_num=1&per_page=1000 HTTP/1.1" 200 None
# 2023-09-14 16:00:13,525-25650-DEBUG-Zentra readings found
# 2023-09-14 16:00:13,526-25650-DEBUG-transformed_reading type <class 'dict_values'>: dict_values([{'data_datetime': datetime.datetime(2023, 9, 14, 19, 45, tzinfo=datetime.timezone.utc), 'atemp': 20.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 71.6}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 40, tzinfo=datetime.timezone.utc), 'atemp': 19.7, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 71.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 35, tzinfo=datetime.timezone.utc), 'atemp': 19.4, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 71.3}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 30, tzinfo=datetime.timezone.utc), 'atemp': 18.7, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 73.5}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 25, tzinfo=datetime.timezone.utc), 'atemp': 18.5, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 74.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 20, tzinfo=datetime.timezone.utc), 'atemp': 18.7, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 74.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 15, tzinfo=datetime.timezone.utc), 'atemp': 18.6, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 73.4}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 10, tzinfo=datetime.timezone.utc), 'atemp': 18.8, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 70.7}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 5, tzinfo=datetime.timezone.utc), 'atemp': 18.7, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 71.3}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 0, tzinfo=datetime.timezone.utc), 'atemp': 18.8, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 72.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 55, tzinfo=datetime.timezone.utc), 'atemp': 19.2, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 68.6}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 50, tzinfo=datetime.timezone.utc), 'atemp': 18.9, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 71.7}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 45, tzinfo=datetime.timezone.utc), 'atemp': 19.1, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 73.4}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 40, tzinfo=datetime.timezone.utc), 'atemp': 19.6, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 73.2}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 35, tzinfo=datetime.timezone.utc), 'atemp': 19.7, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 71.1}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 30, tzinfo=datetime.timezone.utc), 'atemp': 19.2, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 72.4}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 25, tzinfo=datetime.timezone.utc), 'atemp': 18.8, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 74.5}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 20, tzinfo=datetime.timezone.utc), 'atemp': 18.8, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 74.2}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 15, tzinfo=datetime.timezone.utc), 'atemp': 18.6, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 72.3}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 10, tzinfo=datetime.timezone.utc), 'atemp': 18.2, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 71.4}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 5, tzinfo=datetime.timezone.utc), 'atemp': 18.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 73.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 0, tzinfo=datetime.timezone.utc), 'atemp': 18.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 74.3}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 55, tzinfo=datetime.timezone.utc), 'atemp': 18.1, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 74.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 50, tzinfo=datetime.timezone.utc), 'atemp': 18.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 73.4}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 45, tzinfo=datetime.timezone.utc), 'atemp': 18.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 74.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 40, tzinfo=datetime.timezone.utc), 'atemp': 18.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 73.3}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 35, tzinfo=datetime.timezone.utc), 'atemp': 18.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 73.9}, {'data_datetime': d ...
# 2023-09-14 16:00:13,703-25650-DEBUG-Starting new HTTPS connection (1): api.weatherlink.com:443
# {'pagination': {'per_page': 1000, 'page_num': 1, 'next_url': 'https://zentracloud.com/api/v4/get_readings/?device_sn=z6-12564&start_date=2023-09-14+04%3A00%3A00&end_date=2023-09-14+16%3A00%3A00&page_num=2&per_page=1000', 'max_mrid': 242146, 'page_num_readings': 142, 'page_num_outputs': 3408, 'page_start_date': '2023-09-14 04:00:00-04:00', 'page_end_date': '2023-09-14 15:45:00-04:00', 'page_start_mrid': 242002, 'page_end_mrid': 242146}, 'data': {'Air Temperature': [{'metadata': {'device_sn': 'z6-12564', 'device_name': 'envwx-meter-fo', 'port_number': 1, 'sensor_sn': 'ATM-410006006', 'sensor_name': 'ATMOS 41', 'units': ' °C'}, 'readings': [{'timestamp_utc': 1694720700, 'datetime': '2023-09-14 15:45:00-04:00', 'tz_offset': -14400, 'value': 20.0, 'precision': 1, 'mrid': 242146, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694720400, 'datetime': '2023-09-14 15:40:00-04:00', 'tz_offset': -14400, 'value': 19.7, 'precision': 1, 'mrid': 242145, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694720100, 'datetime': '2023-09-14 15:35:00-04:00', 'tz_offset': -14400, 'value': 19.4, 'precision': 1, 'mrid': 242144, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694719800, 'datetime': '2023-09-14 15:30:00-04:00', 'tz_offset': -14400, 'value': 18.7, 'precision': 1, 'mrid': 242143, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694719500, 'datetime': '2023-09-14 15:25:00-04:00', 'tz_offset': -14400, 'value': 18.5, 'precision': 1, 'mrid': 242142, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694719200, 'datetime': '2023-09-14 15:20:00-04:00', 'tz_offset': -14400, 'value': 18.7, 'precision': 1, 'mrid': 242141, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694718900, 'datetime': '2023-09-14 15:15:00-04:00', 'tz_offset': -14400, 'value': 18.6, 'precision': 1, 'mrid': 242140, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694718600, 'datetime': '2023-09-14 15:10:00-04:00', 'tz_offset': -14400, 'value': 18.8, 'precision': 1, 'mrid': 242139, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694718300, 'datetime': '2023-09-14 15:05:00-04:00', 'tz_offset': -14400, 'value': 18.7, 'precision': 1, 'mrid': 242138, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694718000, 'datetime': '2023-09-14 15:00:00-04:00', 'tz_offset': -14400, 'value': 18.8, 'precision': 1, 'mrid': 242137, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694717700, 'datetime': '2023-09-14 14:55:00-04:00', 'tz_offset': -14400, 'value': 19.2, 'precision': 1, 'mrid': 242136, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694717400, 'datetime': '2023-09-14 14:50:00-04:00', 'tz_offset': -14400, 'value': 18.9, 'precision': 1, 'mrid': 242135, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694717100, 'datetime': '2023-09-14 14:45:00-04:00', 'tz_offset': -14400, 'value': 19.1, 'precision': 1, 'mrid': 242134, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694716800, 'datetime': '2023-09-14 14:40:00-04:00', 'tz_offset': -14400, 'value': 19.6, 'precision': 1, 'mrid': 242133, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694716500, 'datetime': '2023-09-14 14:35:00-04:00', 'tz_offset': -14400, 'value': 19.7, 'precision': 1, 'mrid': 242132, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694716200, 'datetime': '2023-09-14 14:30:00-04:00', 'tz_offset': -14400, 'value': 19.2, 'precision': 1, 'mrid': 242131, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694715900, 'datetime': '2023-09-14 14:25:00-04:00', 'tz_offset': -14400, 'value': 18.8, 'precision': 1, 'mrid': 242130, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694715600, 'datetime': '2023-09-14 14:20:00-04:00', 'tz_offset': -14400, 'value': 18.8, 'precision': 1, 'mrid': 242129, 'error_flag': False ...
# 2023-09-14 16:00:14,008-25650-DEBUG-https://api.weatherlink.com:443 "GET /v2/historic/117005?api-key=aoqdcbirudd1sarq6erfj6tgtw67sbvo&t=1694721613&start-timestamp=1694678400&end-timestamp=1694721600&api-signature=7ea7d4cc9bdf830dc848bc06027e29a99540d56e5e1035c2224074d66786b5a9 HTTP/1.1" 200 None
# 2023-09-14 16:00:14,167-25650-DEBUG-transformed_reading type <class 'list'>: [{'data_datetime': datetime.datetime(2023, 9, 14, 12, 5, tzinfo=datetime.timezone.utc), 'atemp': 941488148.89, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 10, tzinfo=datetime.timezone.utc), 'atemp': 941488315.56, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 15, tzinfo=datetime.timezone.utc), 'atemp': 941488482.22, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 20, tzinfo=datetime.timezone.utc), 'atemp': 941488648.89, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 25, tzinfo=datetime.timezone.utc), 'atemp': 941488815.56, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 30, tzinfo=datetime.timezone.utc), 'atemp': 941488982.22, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 35, tzinfo=datetime.timezone.utc), 'atemp': 941489148.89, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 40, tzinfo=datetime.timezone.utc), 'atemp': 941489315.56, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 45, tzinfo=datetime.timezone.utc), 'atemp': 941489482.22, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 50, tzinfo=datetime.timezone.utc), 'atemp': 941489648.89, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 55, tzinfo=datetime.timezone.utc), 'atemp': 941489815.56, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 0, tzinfo=datetime.timezone.utc), 'atemp': 941489982.22, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 5, tzinfo=datetime.timezone.utc), 'atemp': 941490148.89, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 10, tzinfo=datetime.timezone.utc), 'atemp': 941490315.56, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 15, tzinfo=datetime.timezone.utc), 'atemp': 941490482.22, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 20, tzinfo=datetime.timezone.utc), 'atemp': 941490648.89, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 25, tzinfo=datetime.timezone.utc), 'atemp': 941490815.56, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 30, tzinfo=datetime.timezone.utc), 'atemp': 941490982.22, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 35, tzinfo=datetime.timezone.utc), 'atemp': 941491148.89, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 40, tzinfo=datetime.timezone.utc), 'atemp': 941491315.56, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 45, tzinfo=datetime.timezone.utc), 'atemp': 941491482.22, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 50, tzinfo=datetime.timezone.utc), 'atemp': 941491648.89, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 55, tzinfo=datetime.timezone.utc), 'atemp': 941491815.56, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 0, tzinfo=datetime.timezone.utc), 'atemp': 941491982.22, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 5, tzinfo=datetime.timezone.utc), 'atemp': 941492148.89, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 10, tzinfo=datetime.timezone.utc), 'atemp': 941492315.56, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 15, tzinfo=datetime.timezone.utc), 'atemp': 941492482.22, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 20, tzinfo=datetime.timezone.utc), 'atemp': 941492648.89, 'pcpn': 0.0, 'relh': 96}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 25, tzinfo=datetime.timezone.utc), 'at ...
# 2023-09-14 16:00:14,266-25650-DEBUG-Starting new HTTPS connection (1): api.specconnect.net:6703
# 2023-09-14 16:00:14,674-25650-DEBUG-https://api.specconnect.net:6703 "GET /api/Customer/GetDataInDateTimeRange?customerApiKey=11a5c3a939856b08677b7a072f8e6865&serialNumber=50400123&startDate=09-14-2023+04%3A00&endDate=09-14-2023+16%3A00 HTTP/1.1" 200 332443
# 2023-09-14 16:00:15,021-25650-DEBUG-transformed_reading type <class 'list'>: [{'data_datetime': datetime.datetime(2023, 9, 14, 8, 0, tzinfo=datetime.timezone.utc), 'atemp': 6.33, 'pcpn': 0.0, 'relh': 99.6}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 5, tzinfo=datetime.timezone.utc), 'atemp': 6.5, 'pcpn': 0.0, 'relh': 99.7}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 10, tzinfo=datetime.timezone.utc), 'atemp': 6.56, 'pcpn': 0.0, 'relh': 99.7}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 15, tzinfo=datetime.timezone.utc), 'atemp': 6.83, 'pcpn': 0.0, 'relh': 99.7}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 20, tzinfo=datetime.timezone.utc), 'atemp': 6.78, 'pcpn': 0.0, 'relh': 99.8}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 25, tzinfo=datetime.timezone.utc), 'atemp': 6.33, 'pcpn': 0.0, 'relh': 99.7}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 30, tzinfo=datetime.timezone.utc), 'atemp': 6.56, 'pcpn': 0.0, 'relh': 99.7}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 35, tzinfo=datetime.timezone.utc), 'atemp': 6.39, 'pcpn': 0.0, 'relh': 99.7}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 40, tzinfo=datetime.timezone.utc), 'atemp': 6.33, 'pcpn': 0.0, 'relh': 99.7}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 45, tzinfo=datetime.timezone.utc), 'atemp': 6.56, 'pcpn': 0.0, 'relh': 99.8}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 50, tzinfo=datetime.timezone.utc), 'atemp': 6.39, 'pcpn': 0.0, 'relh': 99.8}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 55, tzinfo=datetime.timezone.utc), 'atemp': 6.28, 'pcpn': 0.0, 'relh': 99.8}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 0, tzinfo=datetime.timezone.utc), 'atemp': 6.33, 'pcpn': 0.0, 'relh': 99.8}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 5, tzinfo=datetime.timezone.utc), 'atemp': 6.5, 'pcpn': 0.0, 'relh': 99.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 10, tzinfo=datetime.timezone.utc), 'atemp': 6.56, 'pcpn': 0.0, 'relh': 99.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 15, tzinfo=datetime.timezone.utc), 'atemp': 6.56, 'pcpn': 0.0, 'relh': 99.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 20, tzinfo=datetime.timezone.utc), 'atemp': 6.28, 'pcpn': 0.0, 'relh': 99.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 25, tzinfo=datetime.timezone.utc), 'atemp': 6.06, 'pcpn': 0.0, 'relh': 99.8}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 30, tzinfo=datetime.timezone.utc), 'atemp': 5.94, 'pcpn': 0.0, 'relh': 99.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 35, tzinfo=datetime.timezone.utc), 'atemp': 5.72, 'pcpn': 0.0, 'relh': 99.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 40, tzinfo=datetime.timezone.utc), 'atemp': 5.89, 'pcpn': 0.0, 'relh': 99.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 45, tzinfo=datetime.timezone.utc), 'atemp': 5.89, 'pcpn': 0.0, 'relh': 99.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 50, tzinfo=datetime.timezone.utc), 'atemp': 5.72, 'pcpn': 0.0, 'relh': 99.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 55, tzinfo=datetime.timezone.utc), 'atemp': 5.94, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 0, tzinfo=datetime.timezone.utc), 'atemp': 5.94, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 5, tzinfo=datetime.timezone.utc), 'atemp': 5.83, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 10, tzinfo=datetime.timezone.utc), 'atemp': 6.22, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 15, tzinfo=datetime.timezone.utc), 'atemp': 6.11, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 20, tzinfo=datetime.timezone.utc), 'atemp': 5.94, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 25, tzinfo=datetime.timezone.utc), 'atemp': 6.17, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': ...
# 2023-09-14 16:00:15,065-25650-DEBUG-Starting new HTTPS connection (1): webservice.hobolink.com:443
# 2023-09-14 16:00:15,446-25650-DEBUG-https://webservice.hobolink.com:443 "POST /ws/auth/token HTTP/1.1" 200 90
# 2023-09-14 16:00:15,454-25650-DEBUG-Starting new HTTPS connection (1): webservice.hobolink.com:443
# 2023-09-14 16:00:17,117-25650-DEBUG-https://webservice.hobolink.com:443 "GET /ws/data/file/JSON/user/12848?loggers=21092695&start_date_time=2023-09-14+08%3A00%3A00&end_date_time=2023-09-14+20%3A00%3A00 HTTP/1.1" 200 7894
# 2023-09-14 16:00:17,132-25650-DEBUG-transformed_reading type <class 'list'>: [{'data_datetime': datetime.datetime(2023, 9, 14, 12, 0, tzinfo=datetime.timezone.utc), 'atemp': 5.77, 'relh': 98.9, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 5, tzinfo=datetime.timezone.utc), 'atemp': 6.08, 'relh': 99.1, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 10, tzinfo=datetime.timezone.utc), 'atemp': 6.1, 'relh': 99.2, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 15, tzinfo=datetime.timezone.utc), 'atemp': 6.03, 'relh': 99.2, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 20, tzinfo=datetime.timezone.utc), 'atemp': 6.05, 'relh': 99.1, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 25, tzinfo=datetime.timezone.utc), 'atemp': 5.87, 'relh': 99.2, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 30, tzinfo=datetime.timezone.utc), 'atemp': 5.82, 'relh': 99.2, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 35, tzinfo=datetime.timezone.utc), 'atemp': 5.69, 'relh': 99.2, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 40, tzinfo=datetime.timezone.utc), 'atemp': 5.87, 'relh': 99.4, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 45, tzinfo=datetime.timezone.utc), 'atemp': 5.92, 'relh': 99.4, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 50, tzinfo=datetime.timezone.utc), 'atemp': 5.74, 'relh': 99.3, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 55, tzinfo=datetime.timezone.utc), 'atemp': 5.67, 'relh': 99.5, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 0, tzinfo=datetime.timezone.utc), 'atemp': 5.74, 'relh': 99.3, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 5, tzinfo=datetime.timezone.utc), 'atemp': 5.77, 'relh': 99.4, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 10, tzinfo=datetime.timezone.utc), 'atemp': 5.87, 'relh': 99.5, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 15, tzinfo=datetime.timezone.utc), 'atemp': 5.85, 'relh': 99.5, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 20, tzinfo=datetime.timezone.utc), 'atemp': 5.62, 'relh': 99.4, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 25, tzinfo=datetime.timezone.utc), 'atemp': 5.74, 'relh': 99.6, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 30, tzinfo=datetime.timezone.utc), 'atemp': 5.72, 'relh': 99.6, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 35, tzinfo=datetime.timezone.utc), 'atemp': 5.44, 'relh': 99.4, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 40, tzinfo=datetime.timezone.utc), 'atemp': 5.33, 'relh': 99.5, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 45, tzinfo=datetime.timezone.utc), 'atemp': 5.39, 'relh': 99.5, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 50, tzinfo=datetime.timezone.utc), 'atemp': 5.26, 'relh': 99.6, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 55, tzinfo=datetime.timezone.utc), 'atemp': 5.54, 'relh': 99.8, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 0, tzinfo=datetime.timezone.utc), 'atemp': 5.57, 'relh': 99.8, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 5, tzinfo=datetime.timezone.utc), 'atemp': 5.39, 'relh': 99.6, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 10, tzinfo=datetime.timezone.utc), 'atemp': 5.77, 'relh': 99.9, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 15, tzinfo=datetime.timezone.utc), 'atemp': 5.44, 'relh': 99.6, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 20, tzinfo=datetime.timezone.utc), 'atemp': 5.49, 'relh': 99.7, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 25, tzinfo=datetime.timezone.utc), 'atemp': 5.82, 'relh': 99.9, 'pcpn': 0.0}, ...
# 2023-09-14 16:00:17,185-25650-DEBUG-Starting new HTTP connection (1): api.rainwise.net:80
# 2023-09-14 16:00:17,294-25650-DEBUG-http://api.rainwise.net:80 "GET /main/v1.5/registered/get-historical.php?username=200000000500&sid=66af9e2c2d360730fc4559aad6472056&pid=66af9e2c2d360730fc4559aad6472056&mac=200000000500&format=json&interval=5&sdate=2023-09-14+04%3A00%3A00-04%3A00&edate=2023-09-14+16%3A00%3A00-04%3A00 HTTP/1.1" 200 None
# 2023-09-14 16:00:17,342-25650-DEBUG-transformed_reading type <class 'list'>: [{'data_datetime': datetime.datetime(2023, 9, 14, 8, 0, tzinfo=datetime.timezone.utc), 'atemp': 6.33, 'pcpn': 0.0, 'relh': 98.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 15, tzinfo=datetime.timezone.utc), 'atemp': 6.39, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 30, tzinfo=datetime.timezone.utc), 'atemp': 6.44, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 45, tzinfo=datetime.timezone.utc), 'atemp': 6.11, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 0, tzinfo=datetime.timezone.utc), 'atemp': 6.0, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 15, tzinfo=datetime.timezone.utc), 'atemp': 6.06, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 30, tzinfo=datetime.timezone.utc), 'atemp': 5.94, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 45, tzinfo=datetime.timezone.utc), 'atemp': 5.78, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 0, tzinfo=datetime.timezone.utc), 'atemp': 5.44, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 15, tzinfo=datetime.timezone.utc), 'atemp': 5.5, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 30, tzinfo=datetime.timezone.utc), 'atemp': 5.72, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 45, tzinfo=datetime.timezone.utc), 'atemp': 5.61, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 11, 0, tzinfo=datetime.timezone.utc), 'atemp': 5.39, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 11, 15, tzinfo=datetime.timezone.utc), 'atemp': 5.22, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 11, 30, tzinfo=datetime.timezone.utc), 'atemp': 5.0, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 11, 45, tzinfo=datetime.timezone.utc), 'atemp': 5.0, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 0, tzinfo=datetime.timezone.utc), 'atemp': 5.11, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 15, tzinfo=datetime.timezone.utc), 'atemp': 6.33, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 30, tzinfo=datetime.timezone.utc), 'atemp': 7.67, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 45, tzinfo=datetime.timezone.utc), 'atemp': 8.61, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 0, tzinfo=datetime.timezone.utc), 'atemp': 10.67, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 15, tzinfo=datetime.timezone.utc), 'atemp': 12.33, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 30, tzinfo=datetime.timezone.utc), 'atemp': 13.17, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 45, tzinfo=datetime.timezone.utc), 'atemp': 14.17, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 0, tzinfo=datetime.timezone.utc), 'atemp': 15.56, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 15, tzinfo=datetime.timezone.utc), 'atemp': 16.0, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 30, tzinfo=datetime.timezone.utc), 'atemp': 16.44, 'pcpn': 0.0, 'relh': 96.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 45, tzinfo=datetime.timezone.utc), 'atemp': 16.83, 'pcpn': 0.0, 'relh': 90.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 15, 0, tzinfo=datetime.timezone.utc), 'atemp': 17.67, 'pcpn': 0.0, 'relh': 83.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 15, 15, tzinfo=datetime.timezone.utc), 'atemp': 18.33, 'pcpn': 0.0, 'relh': 78.0},  ...
# 2023-09-14 16:00:17,390-25650-DEBUG-Starting new HTTPS connection (1): industrial.api.ubidots.com:443
# 2023-09-14 16:00:17,970-25650-DEBUG-https://industrial.api.ubidots.com:443 "GET /api/v2.0/devices/62c588591d84724fcb41b255/variables/?page_size=ALL HTTP/1.1" 200 None
# 2023-09-14 16:00:17,980-25650-DEBUG-Starting new HTTPS connection (1): industrial.api.ubidots.com:443
# 2023-09-14 16:00:19,468-25650-DEBUG-https://industrial.api.ubidots.com:443 "POST /api/v1.6/data/raw/series HTTP/1.1" 200 None
# 2023-09-14 16:00:19,532-25650-DEBUG-transformed_reading type <class 'list'>: [{'data_datetime': datetime.datetime(2023, 9, 14, 19, 30, tzinfo=datetime.timezone.utc), 'relh': 54.3971, 'atemp': 21.8003, 'pcpn': 0.0, 'lws0': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 0, tzinfo=datetime.timezone.utc), 'relh': 61.7206, 'atemp': 18.6178, 'pcpn': 0.0, 'lws0': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 30, tzinfo=datetime.timezone.utc), 'relh': 56.4798, 'atemp': 20.8393, 'pcpn': 0.0, 'lws0': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 0, tzinfo=datetime.timezone.utc), 'relh': 52.6982, 'atemp': 21.9816, 'pcpn': 0.0, 'lws0': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 30, tzinfo=datetime.timezone.utc), 'relh': 51.1604, 'atemp': 22.9455, 'pcpn': 0.0, 'lws0': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 0, tzinfo=datetime.timezone.utc), 'relh': 45.9334, 'atemp': 24.9031, 'pcpn': 0.0, 'lws0': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 16, 30, tzinfo=datetime.timezone.utc), 'relh': 47.239, 'atemp': 26.2696, 'pcpn': 0.0, 'lws0': 0.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 16, 0, tzinfo=datetime.timezone.utc), 'relh': 53.4007, 'atemp': 24.1778, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 15, 30, tzinfo=datetime.timezone.utc), 'relh': 52.9156, 'atemp': 23.6765, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 15, 0, tzinfo=datetime.timezone.utc), 'relh': 59.0953, 'atemp': 21.8973, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 30, tzinfo=datetime.timezone.utc), 'relh': 63.8671, 'atemp': 20.4092, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 14, 0, tzinfo=datetime.timezone.utc), 'relh': 74.5887, 'atemp': 16.5653, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 30, tzinfo=datetime.timezone.utc), 'relh': 82.2922, 'atemp': 14.6787, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 13, 0, tzinfo=datetime.timezone.utc), 'relh': 93.278, 'atemp': 11.5456, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 30, tzinfo=datetime.timezone.utc), 'relh': 100.0, 'atemp': 6.85923, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 12, 0, tzinfo=datetime.timezone.utc), 'relh': 100.0, 'atemp': 7.07422, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 11, 30, tzinfo=datetime.timezone.utc), 'relh': 100.0, 'atemp': 4.5341, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 11, 0, tzinfo=datetime.timezone.utc), 'relh': 100.0, 'atemp': 4.83438, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 30, tzinfo=datetime.timezone.utc), 'relh': 100.0, 'atemp': 4.37798, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 10, 0, tzinfo=datetime.timezone.utc), 'relh': 100.0, 'atemp': 4.98994, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 30, tzinfo=datetime.timezone.utc), 'relh': 100.0, 'atemp': 5.04949, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 9, 0, tzinfo=datetime.timezone.utc), 'relh': 100.0, 'atemp': 4.44769, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 30, tzinfo=datetime.timezone.utc), 'relh': 100.0, 'atemp': 5.05107, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 8, 0, tzinfo=datetime.timezone.utc), 'relh': 100.0, 'atemp': 5.27148, 'pcpn': 0.0, 'lws0': 1.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 20, 0, tzinfo=datetime.timezone.utc), 'atemp': 22.3588, 'pcpn': 0.0, 'lws0': 0.0}]
# 2023-09-14 16:00:19,536-25650-DEBUG-Starting new HTTPS connection (1): zentracloud.com:443
# relh
# atemp
# pcpn
# lws0
# 2023-09-14 16:00:32,445-25650-DEBUG-https://zentracloud.com:443 "GET /api/v4/get_readings/?device_sn=z6-20553&start_date=2023-09-14+04%3A00%3A00&end_date=2023-09-14+16%3A00%3A00&page_num=1&per_page=1000 HTTP/1.1" 200 None
# 2023-09-14 16:00:32,549-25650-DEBUG-Zentra readings found
# 2023-09-14 16:00:32,550-25650-DEBUG-transformed_reading type <class 'dict_values'>: dict_values([{'data_datetime': datetime.datetime(2023, 9, 14, 19, 45, tzinfo=datetime.timezone.utc), 'atemp': 19.9, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 58.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 40, tzinfo=datetime.timezone.utc), 'atemp': 19.7, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 59.7}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 35, tzinfo=datetime.timezone.utc), 'atemp': 19.3, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 59.1}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 30, tzinfo=datetime.timezone.utc), 'atemp': 18.7, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 61.8}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 25, tzinfo=datetime.timezone.utc), 'atemp': 18.5, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 62.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 20, tzinfo=datetime.timezone.utc), 'atemp': 18.7, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 61.4}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 15, tzinfo=datetime.timezone.utc), 'atemp': 18.7, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 60.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 10, tzinfo=datetime.timezone.utc), 'atemp': 18.8, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 57.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 5, tzinfo=datetime.timezone.utc), 'atemp': 18.9, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 58.4}, {'data_datetime': datetime.datetime(2023, 9, 14, 19, 0, tzinfo=datetime.timezone.utc), 'atemp': 18.9, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 59.4}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 55, tzinfo=datetime.timezone.utc), 'atemp': 19.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 57.3}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 50, tzinfo=datetime.timezone.utc), 'atemp': 18.8, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 59.3}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 45, tzinfo=datetime.timezone.utc), 'atemp': 18.8, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 60.6}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 40, tzinfo=datetime.timezone.utc), 'atemp': 19.6, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 57.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 35, tzinfo=datetime.timezone.utc), 'atemp': 19.7, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 56.9}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 30, tzinfo=datetime.timezone.utc), 'atemp': 19.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 60.7}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 25, tzinfo=datetime.timezone.utc), 'atemp': 19.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 60.4}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 20, tzinfo=datetime.timezone.utc), 'atemp': 19.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 60.2}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 15, tzinfo=datetime.timezone.utc), 'atemp': 18.6, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 61.3}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 10, tzinfo=datetime.timezone.utc), 'atemp': 18.1, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 61.4}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 5, tzinfo=datetime.timezone.utc), 'atemp': 17.9, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 62.8}, {'data_datetime': datetime.datetime(2023, 9, 14, 18, 0, tzinfo=datetime.timezone.utc), 'atemp': 17.9, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 65.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 55, tzinfo=datetime.timezone.utc), 'atemp': 18.0, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 63.0}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 50, tzinfo=datetime.timezone.utc), 'atemp': 17.9, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 63.1}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 45, tzinfo=datetime.timezone.utc), 'atemp': 17.8, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 64.8}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 40, tzinfo=datetime.timezone.utc), 'atemp': 17.9, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 62.2}, {'data_datetime': datetime.datetime(2023, 9, 14, 17, 35, tzinfo=datetime.timezone.utc), 'atemp': 17.8, 'lws0': 0.0, 'pcpn': 0.0, 'relh': 64.2}, {'data_datetime': d ...
# {'pagination': {'per_page': 1000, 'page_num': 1, 'next_url': 'https://zentracloud.com/api/v4/get_readings/?device_sn=z6-20553&start_date=2023-09-14+04%3A00%3A00&end_date=2023-09-14+16%3A00%3A00&page_num=2&per_page=1000', 'max_mrid': 44744, 'page_num_readings': 142, 'page_num_outputs': 3408, 'page_start_date': '2023-09-14 04:00:00-04:00', 'page_end_date': '2023-09-14 15:45:00-04:00', 'page_start_mrid': 44603, 'page_end_mrid': 44744}, 'data': {'Air Temperature': [{'metadata': {'device_sn': 'z6-20553', 'device_name': 'envwx-meter-fo2', 'port_number': 1, 'sensor_sn': 'ATM-410008286', 'sensor_name': 'ATMOS 41', 'units': ' °C'}, 'readings': [{'timestamp_utc': 1694720700, 'datetime': '2023-09-14 15:45:00-04:00', 'tz_offset': -14400, 'value': 19.9, 'precision': 1, 'mrid': 44744, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694720400, 'datetime': '2023-09-14 15:40:00-04:00', 'tz_offset': -14400, 'value': 19.7, 'precision': 1, 'mrid': 44743, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694720100, 'datetime': '2023-09-14 15:35:00-04:00', 'tz_offset': -14400, 'value': 19.3, 'precision': 1, 'mrid': 44742, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694719800, 'datetime': '2023-09-14 15:30:00-04:00', 'tz_offset': -14400, 'value': 18.7, 'precision': 1, 'mrid': 44741, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694719500, 'datetime': '2023-09-14 15:25:00-04:00', 'tz_offset': -14400, 'value': 18.5, 'precision': 1, 'mrid': 44740, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694719200, 'datetime': '2023-09-14 15:20:00-04:00', 'tz_offset': -14400, 'value': 18.7, 'precision': 1, 'mrid': 44739, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694718900, 'datetime': '2023-09-14 15:15:00-04:00', 'tz_offset': -14400, 'value': 18.7, 'precision': 1, 'mrid': 44738, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694718600, 'datetime': '2023-09-14 15:10:00-04:00', 'tz_offset': -14400, 'value': 18.8, 'precision': 1, 'mrid': 44737, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694718300, 'datetime': '2023-09-14 15:05:00-04:00', 'tz_offset': -14400, 'value': 18.9, 'precision': 1, 'mrid': 44736, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694718000, 'datetime': '2023-09-14 15:00:00-04:00', 'tz_offset': -14400, 'value': 18.9, 'precision': 1, 'mrid': 44735, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694717700, 'datetime': '2023-09-14 14:55:00-04:00', 'tz_offset': -14400, 'value': 19.0, 'precision': 1, 'mrid': 44734, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694717400, 'datetime': '2023-09-14 14:50:00-04:00', 'tz_offset': -14400, 'value': 18.8, 'precision': 1, 'mrid': 44733, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694717100, 'datetime': '2023-09-14 14:45:00-04:00', 'tz_offset': -14400, 'value': 18.8, 'precision': 1, 'mrid': 44732, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694716800, 'datetime': '2023-09-14 14:40:00-04:00', 'tz_offset': -14400, 'value': 19.6, 'precision': 1, 'mrid': 44731, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694716500, 'datetime': '2023-09-14 14:35:00-04:00', 'tz_offset': -14400, 'value': 19.7, 'precision': 1, 'mrid': 44730, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694716200, 'datetime': '2023-09-14 14:30:00-04:00', 'tz_offset': -14400, 'value': 19.0, 'precision': 1, 'mrid': 44729, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694715900, 'datetime': '2023-09-14 14:25:00-04:00', 'tz_offset': -14400, 'value': 19.0, 'precision': 1, 'mrid': 44728, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1694715600, 'datetime': '2023-09-14 14:20:00-04:00', 'tz_offset': -14400, 'value': 19.0, 'precision': 1, 'mrid': 44727, 'error_flag': False, 'error_description ...
#         station_id station_type                            request_id  \
# 0     EWX-METER-FO       ZENTRA  08fa3765-ead5-4f7c-a755-111a75b8bd3c
# 1     EWX-METER-FO       ZENTRA  08fa3765-ead5-4f7c-a755-111a75b8bd3c
# 2     EWX-METER-FO       ZENTRA  08fa3765-ead5-4f7c-a755-111a75b8bd3c
# 3     EWX-METER-FO       ZENTRA  08fa3765-ead5-4f7c-a755-111a75b8bd3c
# 4     EWX-METER-FO       ZENTRA  08fa3765-ead5-4f7c-a755-111a75b8bd3c
# ..             ...          ...                                   ...
# 708  EWX-METER-FO2       ZENTRA  f42a6612-7a1d-4d79-a695-d45aecb7aa17
# 709  EWX-METER-FO2       ZENTRA  f42a6612-7a1d-4d79-a695-d45aecb7aa17
# 710  EWX-METER-FO2       ZENTRA  f42a6612-7a1d-4d79-a695-d45aecb7aa17
# 711  EWX-METER-FO2       ZENTRA  f42a6612-7a1d-4d79-a695-d45aecb7aa17
# 712  EWX-METER-FO2       ZENTRA  f42a6612-7a1d-4d79-a695-d45aecb7aa17
#
#                     request_datetime  \
# 0   2023-09-15 00:00:10.797837+00:00
# 1   2023-09-15 00:00:10.797837+00:00
# 2   2023-09-15 00:00:10.797837+00:00
# 3   2023-09-15 00:00:10.797837+00:00
# 4   2023-09-15 00:00:10.797837+00:00
# ..                               ...
# 708 2023-09-15 00:00:19.534053+00:00
# 709 2023-09-15 00:00:19.534053+00:00
# 710 2023-09-15 00:00:19.534053+00:00
# 711 2023-09-15 00:00:19.534053+00:00
# 712 2023-09-15 00:00:19.534053+00:00
#
#                                          time_interval  \
# 0    {'start': 2023-09-14 08:00:00+00:00, 'end': 20...
# 1    {'start': 2023-09-14 08:00:00+00:00, 'end': 20...
# 2    {'start': 2023-09-14 08:00:00+00:00, 'end': 20...
# 3    {'start': 2023-09-14 08:00:00+00:00, 'end': 20...
# 4    {'start': 2023-09-14 08:00:00+00:00, 'end': 20...
# ..                                                 ...
# 708  {'start': 2023-09-14 08:00:00+00:00, 'end': 20...
# 709  {'start': 2023-09-14 08:00:00+00:00, 'end': 20...
# 710  {'start': 2023-09-14 08:00:00+00:00, 'end': 20...
# 711  {'start': 2023-09-14 08:00:00+00:00, 'end': 20...
# 712  {'start': 2023-09-14 08:00:00+00:00, 'end': 20...
#
#                 data_datetime  atemp  pcpn  relh  lws0
# 0   2023-09-14 19:45:00+00:00   20.0   0.0  71.6   0.0
# 1   2023-09-14 19:40:00+00:00   19.7   0.0  71.9   0.0
# 2   2023-09-14 19:35:00+00:00   19.4   0.0  71.3   0.0
# 3   2023-09-14 19:30:00+00:00   18.7   0.0  73.5   0.0
# 4   2023-09-14 19:25:00+00:00   18.5   0.0  74.9   0.0
# ..                        ...    ...   ...   ...   ...
# 708 2023-09-14 08:20:00+00:00    6.6   0.0  96.4   5.0
# 709 2023-09-14 08:15:00+00:00    6.7   0.0  95.5   5.0
# 710 2023-09-14 08:10:00+00:00    6.5   0.0  96.7   5.0
# 711 2023-09-14 08:05:00+00:00    6.7   0.0  95.7   5.0
# 712 2023-09-14 08:00:00+00:00    6.6   0.0  95.9   5.0
#
# [713 rows x 10 columns]

# %%
from ewx_pws.weather_store import WeatherStore
dbfile = '../../tmp_ewx_pws.sqlite3'
weatherstore = WeatherStore(dbfile)
weatherstore.engine
weatherstore.connection

# %%
from sqlalchemy import inspect, text
insp = inspect(weatherstore.engine)
insp.has_table('stations')
# Out:
# True

# %%
tablename = 'stations'
import json
from datetime import datetime

from ewx_pws.ewx_pws import STATION_CLASS_TYPES as station_class_types
result = weatherstore.connection.execute(text(f"select * from {tablename}"))
stations = {}
for row in result:
    station_config = dict(zip(row._mapping.keys(), row._mapping.values()))
    if 'index' in station_config: del station_config['index'] 
    station_config.update(json.loads(station_config['station_config']))
    print(station_config)
    station_type = station_config['station_type']
    station_id = station_config['station_id']
    station_config['install_date'] = datetime.fromisoformat(station_config['install_date'])
    stations[station_id] = station_class_types[station_type].init_from_dict(station_config)
# Out:
# {'station_id': 'EWX-METER-FO', 'station_type': 'ZENTRA', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"sn":"z6-12564","token":"5b8f637a718b9e3ad6e31eec81f0b51d91ac38bd"}', 'sn': 'z6-12564', 'token': '5b8f637a718b9e3ad6e31eec81f0b51d91ac38bd'}
# {'station_id': 'EWXDAVIS01', 'station_type': 'DAVIS', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"sn":"117005","apikey":"aoqdcbirudd1sarq6erfj6tgtw67sbvo","apisec":"elvr77yhdx3p0286cwnnqqstdwqg8zxf"}', 'sn': '117005', 'apikey': 'aoqdcbirudd1sarq6erfj6tgtw67sbvo', 'apisec': 'elvr77yhdx3p0286cwnnqqstdwqg8zxf'}
# {'station_id': 'EWXSPECTRUM01', 'station_type': 'SPECTRUM', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"sn":"50400123","apikey":"11a5c3a939856b08677b7a072f8e6865"}', 'sn': '50400123', 'apikey': '11a5c3a939856b08677b7a072f8e6865'}
# {'station_id': 'EWXONSET01', 'station_type': 'ONSET', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"sn":"21092695","client_id":"Enviroweather_WS","client_secret":"75d2b7f58f5d0cac699f5b9616318be268057de6","ret_form":"JSON","user_id":"12848","sensor_sn":{"atemp":"21079936-1","pcpn":"21085496-1","relh":"21079936-2"}}', 'sn': '21092695', 'client_id': 'Enviroweather_WS', 'client_secret': '75d2b7f58f5d0cac699f5b9616318be268057de6', 'ret_form': 'JSON', 'user_id': '12848', 'sensor_sn': {'atemp': '21079936-1', 'pcpn': '21085496-1', 'relh': '21079936-2'}}
# {'station_id': 'EWXRAINWISE01', 'station_type': 'RAINWISE', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"sid":"66af9e2c2d360730fc4559aad6472056","pid":"66af9e2c2d360730fc4559aad6472056","ret_form":"json","mac":"200000000500","username":"200000000500"}', 'sid': '66af9e2c2d360730fc4559aad6472056', 'pid': '66af9e2c2d360730fc4559aad6472056', 'ret_form': 'json', 'mac': '200000000500', 'username': '200000000500'}
# {'station_id': 'EWXLOCOMOS06', 'station_type': 'LOCOMOS', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"token":"BBFF-MMZJs422YNyUyA3sh3ePXKAnMZp7yz","id":"62c588591d84724fcb41b255"}', 'token': 'BBFF-MMZJs422YNyUyA3sh3ePXKAnMZp7yz', 'id': '62c588591d84724fcb41b255'}
# {'station_id': 'EWX-METER-FO2', 'station_type': 'ZENTRA', 'install_date': '2023-09-10', 'tz': 'ET', 'station_config': '{"sn":"z6-20553","token":"12cc21d9f697e478885cca9b65307d27872dfb18"}', 'sn': 'z6-20553', 'token': '12cc21d9f697e478885cca9b65307d27872dfb18'}

# %%
# add stations

station_ids = [station.id for station in collector.stations]
print(station_ids)
stations = dict(zip(station_ids, collector.stations))

# %%
weatherstore.stations = None

# %%
def dict_factory(cursor, row):
    d = {}
    for idx, col in enumerate(cursor.description):
        d[col[0]] = row[idx]
    return d


# weatherstore.conn.row_factory = sqlite3.Row 
weatherstore.conn.row_factory = dict_factory
cursor = weatherstore.conn.cursor()

cursor.execute("PRAGMA table_list;")
pprint(cursor.fetchall())
# for row in cursor.fetchall():
#    for k in row.keys():
#        print()

# %%
def dict_factory(cursor, row):
    d = {}
    for idx, col in enumerate(cursor.description):
        d[col[0]] = row[idx]
    return d

def list_tables(conn):
    cursor = conn.cursor()
    cursor.execute("PRAGMA table_list;")
    table_list =  cursor.fetchall()
    cursor.close()
    return(table_list)

def table_columns(conn, tablename):
    cursor = conn.cursor()
    columnsQuery = ("PRAGMA table_info(%s)" % (tablename))
    cursor.execute(columnsQuery)
    columns = [column for column in cursor.fetchall()]
    cursor.close()
    return(columns)

print(list_tables(weatherstore.conn))

# %%
list_tables(weatherstore.conn)

# %%
import pandas
stationsdf = pandas.read_csv(station_config_file,header=0,quotechar="'")
# stations = weatherstore.create_stations_table_from_file(station_config_file)
display(stationsdf)

# %%
nrows = stationsdf.to_sql(name=weatherstore.stations_table, con= weatherstore.conn, if_exists='replace')
nrows

# %%
from sqlalchemy import engine,create_engine

engine = create_engine(f"sqlite:///{dbfile}")
with engine.connect() as conn, conn.begin():
    station_configs = pd.read_sql_table(weatherstore.stations_table, conn)

print(station_configs.to_string())

# %%
sql = f"select * from {weatherstore.stations_table}"
station_configs = pandas.read_sql(sql, con=weatherstore.conn)
display(station_configs)
