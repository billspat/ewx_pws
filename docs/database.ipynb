# %%
import json
from pprint import pprint
import os

from ewx_pws import weather_stations
from ewx_pws.weather_collector import WeatherCollector

import pandas as pd
from IPython.display import display

# %%
station_config_file = "../test_stations.csv"
collector = WeatherCollector.init_from_station_file(station_config_file)
collector.stations
# Out:
# 2023-10-23 09:53:43,264-32443-DEBUG-instantiating EWX-METER-FO
# 2023-10-23 09:53:43,265-32443-DEBUG-instantiating EWXDAVIS01
# 2023-10-23 09:53:43,266-32443-DEBUG-instantiating EWXSPECTRUM01
# 2023-10-23 09:53:43,266-32443-DEBUG-instantiating EWXONSET01
# 2023-10-23 09:53:43,267-32443-DEBUG-instantiating EWXRAINWISE01
# 2023-10-23 09:53:43,267-32443-DEBUG-instantiating EWXLOCOMOS06
# 2023-10-23 09:53:43,268-32443-DEBUG-instantiating EWX-METER-FO2
# [<ewx_pws.zentra.ZentraStation at 0x110d6b100>,
#  <ewx_pws.davis.DavisStation at 0x111f46910>,
#  <ewx_pws.spectrum.SpectrumStation at 0x110af13a0>,
#  <ewx_pws.onset.OnsetStation at 0x111f468b0>,
#  <ewx_pws.rainwise.RainwiseStation at 0x110d569d0>,
#  <ewx_pws.locomos.LocomosStation at 0x110d567c0>,
#  <ewx_pws.zentra.ZentraStation at 0x110d56460>]

# %%
from ewx_pws.time_intervals import UTCInterval
interval = UTCInterval.previous_interval(delta_mins = 720)

# %%
raw_records, readings_records = collector.collect_readings(interval)
readings_df = pd.DataFrame(readings_records)
display(readings_df)
# Out:
# 2023-10-23 09:53:47,426-32443-DEBUG-Starting new HTTPS connection (1): zentracloud.com:443
# 2023-10-23 09:53:49,552-32443-DEBUG-https://zentracloud.com:443 "GET /api/v4/get_readings/?device_sn=z6-12564&start_date=2023-10-22+21%3A45%3A00&end_date=2023-10-23+09%3A45%3A00&page_num=1&per_page=1000 HTTP/1.1" 200 None
# 2023-10-23 09:53:50,082-32443-DEBUG-Zentra readings found
# 2023-10-23 09:53:50,084-32443-DEBUG-transformed_reading type <class 'dict_values'>: dict_values([{'data_datetime': datetime.datetime(2023, 10, 23, 13, 45, tzinfo=datetime.timezone.utc), 'atemp': 2.5, 'lws0': 5.0, 'pcpn': 0.102, 'relh': 100.2}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 40, tzinfo=datetime.timezone.utc), 'atemp': 2.3, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.9}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 35, tzinfo=datetime.timezone.utc), 'atemp': 2.2, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 30, tzinfo=datetime.timezone.utc), 'atemp': 1.9, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 98.2}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 25, tzinfo=datetime.timezone.utc), 'atemp': 1.4, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.1}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 20, tzinfo=datetime.timezone.utc), 'atemp': 1.2, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.5}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 15, tzinfo=datetime.timezone.utc), 'atemp': 1.2, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.8}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 10, tzinfo=datetime.timezone.utc), 'atemp': 0.9, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.7}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 5, tzinfo=datetime.timezone.utc), 'atemp': 0.7, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.2}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 0, tzinfo=datetime.timezone.utc), 'atemp': 0.7, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 96.9}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 55, tzinfo=datetime.timezone.utc), 'atemp': 0.5, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 96.7}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 50, tzinfo=datetime.timezone.utc), 'atemp': 0.3, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 96.3}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 45, tzinfo=datetime.timezone.utc), 'atemp': -0.1, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 98.8}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 40, tzinfo=datetime.timezone.utc), 'atemp': -0.2, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.6}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 35, tzinfo=datetime.timezone.utc), 'atemp': -0.2, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 94.3}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 30, tzinfo=datetime.timezone.utc), 'atemp': -0.2, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 92.9}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 25, tzinfo=datetime.timezone.utc), 'atemp': -0.6, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 91.9}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 20, tzinfo=datetime.timezone.utc), 'atemp': -1.5, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 96.2}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 15, tzinfo=datetime.timezone.utc), 'atemp': -1.7, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.3}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 10, tzinfo=datetime.timezone.utc), 'atemp': -2.0, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 98.7}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 5, tzinfo=datetime.timezone.utc), 'atemp': -1.7, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 0, tzinfo=datetime.timezone.utc), 'atemp': -1.9, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.8}, {'data_datetime': datetime.datetime(2023, 10, 23, 11, 55, tzinfo=datetime.timezone.utc), 'atemp': -2.1, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.6}, {'data_datetime': datetime.datetime(2023, 10, 23, 11, 50, tzinfo=datetime.timezone.utc), 'atemp': -1.8, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.2}, {'data_datetime': datetime.datetime(2023, 10, 23, 11, 45, tzinfo=datetime.timezone.utc), 'atemp': -1.8, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.2}, {'data_datetime': datetime.datetime(2023, 10, 23, 11, 40, tzinfo=datetime.timezone.utc), 'atemp': -1.5, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 96.1}, {'data_datetime': datetime.datetime(2023, 10, 23, 11, 35, tzinfo=datetime.timezone.utc), 'atemp': -1.5, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 95.2}, { ...
# 2023-10-23 09:53:50,114-32443-DEBUG-Starting new HTTPS connection (1): api.weatherlink.com:443
# {'pagination': {'per_page': 1000, 'page_num': 1, 'next_url': 'https://zentracloud.com/api/v4/get_readings/?device_sn=z6-12564&start_date=2023-10-22+21%3A45%3A00&end_date=2023-10-23+09%3A45%3A00&page_num=2&per_page=1000', 'max_mrid': 253516, 'page_num_readings': 145, 'page_num_outputs': 3480, 'page_start_date': '2023-10-22 21:45:00-04:00', 'page_end_date': '2023-10-23 09:45:00-04:00', 'page_start_mrid': 253372, 'page_end_mrid': 253516}, 'data': {'Air Temperature': [{'metadata': {'device_sn': 'z6-12564', 'device_name': 'envwx-meter-fo', 'port_number': 1, 'sensor_sn': 'ATM-410006006', 'sensor_name': 'ATMOS 41', 'units': ' °C'}, 'readings': [{'timestamp_utc': 1698068700, 'datetime': '2023-10-23 09:45:00-04:00', 'tz_offset': -14400, 'value': 2.5, 'precision': 1, 'mrid': 253516, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698068400, 'datetime': '2023-10-23 09:40:00-04:00', 'tz_offset': -14400, 'value': 2.3, 'precision': 1, 'mrid': 253515, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698068100, 'datetime': '2023-10-23 09:35:00-04:00', 'tz_offset': -14400, 'value': 2.2, 'precision': 1, 'mrid': 253514, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698067800, 'datetime': '2023-10-23 09:30:00-04:00', 'tz_offset': -14400, 'value': 1.9, 'precision': 1, 'mrid': 253513, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698067500, 'datetime': '2023-10-23 09:25:00-04:00', 'tz_offset': -14400, 'value': 1.4, 'precision': 1, 'mrid': 253512, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698067200, 'datetime': '2023-10-23 09:20:00-04:00', 'tz_offset': -14400, 'value': 1.2, 'precision': 1, 'mrid': 253511, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698066900, 'datetime': '2023-10-23 09:15:00-04:00', 'tz_offset': -14400, 'value': 1.2, 'precision': 1, 'mrid': 253510, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698066600, 'datetime': '2023-10-23 09:10:00-04:00', 'tz_offset': -14400, 'value': 0.9, 'precision': 1, 'mrid': 253509, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698066300, 'datetime': '2023-10-23 09:05:00-04:00', 'tz_offset': -14400, 'value': 0.7, 'precision': 1, 'mrid': 253508, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698066000, 'datetime': '2023-10-23 09:00:00-04:00', 'tz_offset': -14400, 'value': 0.7, 'precision': 1, 'mrid': 253507, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698065700, 'datetime': '2023-10-23 08:55:00-04:00', 'tz_offset': -14400, 'value': 0.5, 'precision': 1, 'mrid': 253506, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698065400, 'datetime': '2023-10-23 08:50:00-04:00', 'tz_offset': -14400, 'value': 0.3, 'precision': 1, 'mrid': 253505, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698065100, 'datetime': '2023-10-23 08:45:00-04:00', 'tz_offset': -14400, 'value': -0.1, 'precision': 1, 'mrid': 253504, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698064800, 'datetime': '2023-10-23 08:40:00-04:00', 'tz_offset': -14400, 'value': -0.2, 'precision': 1, 'mrid': 253503, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698064500, 'datetime': '2023-10-23 08:35:00-04:00', 'tz_offset': -14400, 'value': -0.2, 'precision': 1, 'mrid': 253502, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698064200, 'datetime': '2023-10-23 08:30:00-04:00', 'tz_offset': -14400, 'value': -0.2, 'precision': 1, 'mrid': 253501, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698063900, 'datetime': '2023-10-23 08:25:00-04:00', 'tz_offset': -14400, 'value': -0.6, 'precision': 1, 'mrid': 253500, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698063600, 'datetime': '2023-10-23 08:20:00-04:00', 'tz_offset': -14400, 'value': -1.5, 'precision': 1, 'mrid': 253499, 'error_flag': False, 'error_des ...
# 2023-10-23 09:53:50,408-32443-DEBUG-https://api.weatherlink.com:443 "GET /v2/historic/117005?api-key=aoqdcbirudd1sarq6erfj6tgtw67sbvo&t=1698069230&start-timestamp=1698025500&end-timestamp=1698068700&api-signature=1b5d33d335335b21af3e16ef66d24ed237529a773396ff8ca4b446687c622a39 HTTP/1.1" 200 None
# 2023-10-23 09:53:50,589-32443-DEBUG-transformed_reading type <class 'list'>: [{'data_datetime': datetime.datetime(2023, 10, 23, 5, 50, tzinfo=datetime.timezone.utc), 'atemp': 943347648.89, 'pcpn': 0.0, 'relh': 93}, {'data_datetime': datetime.datetime(2023, 10, 23, 5, 55, tzinfo=datetime.timezone.utc), 'atemp': 943347815.56, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 0, tzinfo=datetime.timezone.utc), 'atemp': 943347982.22, 'pcpn': 0.0, 'relh': 93}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 5, tzinfo=datetime.timezone.utc), 'atemp': 943348148.89, 'pcpn': 0.0, 'relh': 93}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 10, tzinfo=datetime.timezone.utc), 'atemp': 943348315.56, 'pcpn': 0.0, 'relh': 93}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 15, tzinfo=datetime.timezone.utc), 'atemp': 943348482.22, 'pcpn': 0.0, 'relh': 93}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 20, tzinfo=datetime.timezone.utc), 'atemp': 943348648.89, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 25, tzinfo=datetime.timezone.utc), 'atemp': 943348815.56, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 30, tzinfo=datetime.timezone.utc), 'atemp': 943348982.22, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 35, tzinfo=datetime.timezone.utc), 'atemp': 943349148.89, 'pcpn': 0.0, 'relh': 93}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 40, tzinfo=datetime.timezone.utc), 'atemp': 943349315.56, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 45, tzinfo=datetime.timezone.utc), 'atemp': 943349482.22, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 50, tzinfo=datetime.timezone.utc), 'atemp': 943349648.89, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 55, tzinfo=datetime.timezone.utc), 'atemp': 943349815.56, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 0, tzinfo=datetime.timezone.utc), 'atemp': 943349982.22, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 5, tzinfo=datetime.timezone.utc), 'atemp': 943350148.89, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 10, tzinfo=datetime.timezone.utc), 'atemp': 943350315.56, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 15, tzinfo=datetime.timezone.utc), 'atemp': 943350482.22, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 20, tzinfo=datetime.timezone.utc), 'atemp': 943350648.89, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 25, tzinfo=datetime.timezone.utc), 'atemp': 943350815.56, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 30, tzinfo=datetime.timezone.utc), 'atemp': 943350982.22, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 35, tzinfo=datetime.timezone.utc), 'atemp': 943351148.89, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 40, tzinfo=datetime.timezone.utc), 'atemp': 943351315.56, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 45, tzinfo=datetime.timezone.utc), 'atemp': 943351482.22, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 50, tzinfo=datetime.timezone.utc), 'atemp': 943351648.89, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 55, tzinfo=datetime.timezone.utc), 'atemp': 943351815.56, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 8, 0, tzinfo=datetime.timezone.utc), 'atemp': 943351982.22, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 8, 5, tzinfo=datetime.timezone.utc), 'atemp': 943352148.89, 'pcpn': 0.0, 'relh': 94}, {'data_datetime': datetime.datetime(2023, 10, 23, 8, 10, tzinfo=datetime.timezone.utc), 'ate ...
# 2023-10-23 09:53:50,665-32443-DEBUG-Starting new HTTPS connection (1): api.specconnect.net:6703
# 2023-10-23 09:53:51,097-32443-DEBUG-https://api.specconnect.net:6703 "GET /api/Customer/GetDataInDateTimeRange?customerApiKey=11a5c3a939856b08677b7a072f8e6865&serialNumber=50400123&startDate=10-22-2023+21%3A45&endDate=10-23-2023+09%3A45 HTTP/1.1" 200 334489
# 2023-10-23 09:53:51,471-32443-DEBUG-transformed_reading type <class 'list'>: [{'data_datetime': datetime.datetime(2023, 10, 23, 1, 45, tzinfo=datetime.timezone.utc), 'atemp': 1.83, 'pcpn': 0.0, 'relh': 96.8}, {'data_datetime': datetime.datetime(2023, 10, 23, 1, 50, tzinfo=datetime.timezone.utc), 'atemp': 2.11, 'pcpn': 0.0, 'relh': 96.9}, {'data_datetime': datetime.datetime(2023, 10, 23, 1, 55, tzinfo=datetime.timezone.utc), 'atemp': 1.94, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 0, tzinfo=datetime.timezone.utc), 'atemp': 2.11, 'pcpn': 0.0, 'relh': 97.1}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 5, tzinfo=datetime.timezone.utc), 'atemp': 1.89, 'pcpn': 0.0, 'relh': 97.1}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 10, tzinfo=datetime.timezone.utc), 'atemp': 1.78, 'pcpn': 0.0, 'relh': 97.1}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 15, tzinfo=datetime.timezone.utc), 'atemp': 1.44, 'pcpn': 0.0, 'relh': 97.1}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 20, tzinfo=datetime.timezone.utc), 'atemp': 1.61, 'pcpn': 0.0, 'relh': 97.3}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 25, tzinfo=datetime.timezone.utc), 'atemp': 1.72, 'pcpn': 0.0, 'relh': 97.3}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 30, tzinfo=datetime.timezone.utc), 'atemp': 1.33, 'pcpn': 0.25, 'relh': 97.3}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 35, tzinfo=datetime.timezone.utc), 'atemp': 1.0, 'pcpn': 0.0, 'relh': 97.3}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 40, tzinfo=datetime.timezone.utc), 'atemp': 1.0, 'pcpn': 0.0, 'relh': 97.5}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 45, tzinfo=datetime.timezone.utc), 'atemp': 1.0, 'pcpn': 0.0, 'relh': 97.5}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 50, tzinfo=datetime.timezone.utc), 'atemp': 0.89, 'pcpn': 0.0, 'relh': 97.6}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 55, tzinfo=datetime.timezone.utc), 'atemp': 0.56, 'pcpn': 0.0, 'relh': 97.6}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 0, tzinfo=datetime.timezone.utc), 'atemp': 0.67, 'pcpn': 0.0, 'relh': 97.7}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 5, tzinfo=datetime.timezone.utc), 'atemp': 1.17, 'pcpn': 0.0, 'relh': 97.8}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 10, tzinfo=datetime.timezone.utc), 'atemp': 1.17, 'pcpn': 0.25, 'relh': 97.8}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 15, tzinfo=datetime.timezone.utc), 'atemp': 1.22, 'pcpn': 0.0, 'relh': 97.8}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 20, tzinfo=datetime.timezone.utc), 'atemp': 1.22, 'pcpn': 0.0, 'relh': 97.9}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 25, tzinfo=datetime.timezone.utc), 'atemp': 0.94, 'pcpn': 0.0, 'relh': 97.8}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 30, tzinfo=datetime.timezone.utc), 'atemp': 0.89, 'pcpn': 0.0, 'relh': 97.9}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 35, tzinfo=datetime.timezone.utc), 'atemp': 0.78, 'pcpn': 0.0, 'relh': 97.9}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 40, tzinfo=datetime.timezone.utc), 'atemp': 0.83, 'pcpn': 0.0, 'relh': 98.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 45, tzinfo=datetime.timezone.utc), 'atemp': 0.67, 'pcpn': 0.0, 'relh': 98.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 50, tzinfo=datetime.timezone.utc), 'atemp': 0.33, 'pcpn': 0.0, 'relh': 98.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 55, tzinfo=datetime.timezone.utc), 'atemp': 0.44, 'pcpn': 0.0, 'relh': 98.1}, {'data_datetime': datetime.datetime(2023, 10, 23, 4, 0, tzinfo=datetime.timezone.utc), 'atemp': 0.56, 'pcpn': 0.0, 'relh': 98.1}, {'data_datetime': datetime.datetime(2023, 10, 23, 4, 5, tzinfo=datetime.timezone.utc), 'atemp': 0.5, 'pcpn': 0.25, 'relh': 98.1}, {'data_datetime': datetime.datetime(2023, 10, 23, 4, 10, tzinfo=datetime.timezone.utc), 'atemp': 0.39, 'pcpn': 0.0, 'relh': 98.1}, ...
# 2023-10-23 09:53:51,525-32443-DEBUG-Starting new HTTPS connection (1): webservice.hobolink.com:443
# 2023-10-23 09:53:51,898-32443-DEBUG-https://webservice.hobolink.com:443 "POST /ws/auth/token HTTP/1.1" 200 90
# 2023-10-23 09:53:51,903-32443-DEBUG-Starting new HTTPS connection (1): webservice.hobolink.com:443
# 2023-10-23 09:53:54,954-32443-DEBUG-https://webservice.hobolink.com:443 "GET /ws/data/file/JSON/user/12848?loggers=21092695&start_date_time=2023-10-23+01%3A45%3A00&end_date_time=2023-10-23+13%3A45%3A00 HTTP/1.1" 200 None
# 2023-10-23 09:53:54,982-32443-DEBUG-transformed_reading type <class 'list'>: [{'data_datetime': datetime.datetime(2023, 10, 23, 5, 45, tzinfo=datetime.timezone.utc), 'atemp': 1.1, 'relh': 93.7, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 5, 50, tzinfo=datetime.timezone.utc), 'atemp': 1.15, 'relh': 93.8, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 5, 55, tzinfo=datetime.timezone.utc), 'atemp': 1.1, 'relh': 93.9, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 0, tzinfo=datetime.timezone.utc), 'atemp': 1.26, 'relh': 94.3, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 5, tzinfo=datetime.timezone.utc), 'atemp': 0.96, 'relh': 94.3, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 10, tzinfo=datetime.timezone.utc), 'atemp': 0.71, 'relh': 94.3, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 15, tzinfo=datetime.timezone.utc), 'atemp': 0.47, 'relh': 94.4, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 20, tzinfo=datetime.timezone.utc), 'atemp': 0.55, 'relh': 94.8, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 25, tzinfo=datetime.timezone.utc), 'atemp': 0.93, 'relh': 94.6, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 30, tzinfo=datetime.timezone.utc), 'atemp': 0.71, 'relh': 94.8, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 35, tzinfo=datetime.timezone.utc), 'atemp': 0.38, 'relh': 95.0, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 40, tzinfo=datetime.timezone.utc), 'atemp': 0.27, 'relh': 95.0, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 45, tzinfo=datetime.timezone.utc), 'atemp': 0.25, 'relh': 94.9, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 50, tzinfo=datetime.timezone.utc), 'atemp': 0.19, 'relh': 95.2, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 55, tzinfo=datetime.timezone.utc), 'atemp': 0.27, 'relh': 95.3, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 0, tzinfo=datetime.timezone.utc), 'atemp': 0.55, 'relh': 95.6, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 5, tzinfo=datetime.timezone.utc), 'atemp': 0.33, 'relh': 95.4, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 10, tzinfo=datetime.timezone.utc), 'atemp': 0.25, 'relh': 95.4, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 15, tzinfo=datetime.timezone.utc), 'atemp': 0.27, 'relh': 95.6, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 20, tzinfo=datetime.timezone.utc), 'atemp': 0.41, 'relh': 95.8, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 25, tzinfo=datetime.timezone.utc), 'atemp': 0.3, 'relh': 95.9, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 30, tzinfo=datetime.timezone.utc), 'atemp': 0.11, 'relh': 95.8, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 35, tzinfo=datetime.timezone.utc), 'atemp': 0.3, 'relh': 96.1, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 40, tzinfo=datetime.timezone.utc), 'atemp': 0.13, 'relh': 96.0, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 45, tzinfo=datetime.timezone.utc), 'atemp': 0.05, 'relh': 96.2, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 50, tzinfo=datetime.timezone.utc), 'atemp': -0.06, 'relh': 96.4, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 55, tzinfo=datetime.timezone.utc), 'atemp': 0.11, 'relh': 96.6, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 8, 0, tzinfo=datetime.timezone.utc), 'atemp': 0.13, 'relh': 96.6, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 8, 5, tzinfo=datetime.timezone.utc), 'atemp': 0.02, 'relh': 96.6, 'pcpn': 0.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 8, 10, tzinfo=datetime.timezone.utc), 'atemp': -0.23, 'relh': 97.1, 'pcpn': 0.0},  ...
# 2023-10-23 09:53:55,031-32443-DEBUG-Starting new HTTP connection (1): api.rainwise.net:80
# 2023-10-23 09:53:55,141-32443-DEBUG-http://api.rainwise.net:80 "GET /main/v1.5/registered/get-historical.php?username=200000000500&sid=66af9e2c2d360730fc4559aad6472056&pid=66af9e2c2d360730fc4559aad6472056&mac=200000000500&format=json&interval=5&sdate=2023-10-22+21%3A45%3A00-04%3A00&edate=2023-10-23+09%3A45%3A00-04%3A00 HTTP/1.1" 200 None
# 2023-10-23 09:53:55,185-32443-DEBUG-transformed_reading type <class 'list'>: [{'data_datetime': datetime.datetime(2023, 10, 23, 1, 45, tzinfo=datetime.timezone.utc), 'atemp': 1.5, 'pcpn': 0.0, 'relh': 93.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 0, tzinfo=datetime.timezone.utc), 'atemp': 1.56, 'pcpn': 0.0, 'relh': 94.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 15, tzinfo=datetime.timezone.utc), 'atemp': 1.72, 'pcpn': 0.0, 'relh': 95.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 30, tzinfo=datetime.timezone.utc), 'atemp': 1.28, 'pcpn': 0.0, 'relh': 95.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 2, 45, tzinfo=datetime.timezone.utc), 'atemp': 1.06, 'pcpn': 0.0, 'relh': 95.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 0, tzinfo=datetime.timezone.utc), 'atemp': 0.83, 'pcpn': 0.0, 'relh': 95.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 15, tzinfo=datetime.timezone.utc), 'atemp': 0.83, 'pcpn': 0.0, 'relh': 95.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 30, tzinfo=datetime.timezone.utc), 'atemp': 0.89, 'pcpn': 0.0, 'relh': 96.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 3, 45, tzinfo=datetime.timezone.utc), 'atemp': 0.61, 'pcpn': 0.0, 'relh': 96.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 4, 0, tzinfo=datetime.timezone.utc), 'atemp': 0.39, 'pcpn': 0.0, 'relh': 96.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 4, 15, tzinfo=datetime.timezone.utc), 'atemp': 0.28, 'pcpn': 0.0, 'relh': 96.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 4, 30, tzinfo=datetime.timezone.utc), 'atemp': 0.11, 'pcpn': 0.0, 'relh': 96.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 4, 45, tzinfo=datetime.timezone.utc), 'atemp': 0.28, 'pcpn': 0.0, 'relh': 96.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 5, 0, tzinfo=datetime.timezone.utc), 'atemp': 0.06, 'pcpn': 0.0, 'relh': 96.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 5, 15, tzinfo=datetime.timezone.utc), 'atemp': -0.17, 'pcpn': 0.0, 'relh': 96.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 5, 30, tzinfo=datetime.timezone.utc), 'atemp': -0.06, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 5, 45, tzinfo=datetime.timezone.utc), 'atemp': 0.06, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 0, tzinfo=datetime.timezone.utc), 'atemp': -0.06, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 15, tzinfo=datetime.timezone.utc), 'atemp': -0.06, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 30, tzinfo=datetime.timezone.utc), 'atemp': -0.17, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 6, 45, tzinfo=datetime.timezone.utc), 'atemp': -0.44, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 0, tzinfo=datetime.timezone.utc), 'atemp': -0.22, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 15, tzinfo=datetime.timezone.utc), 'atemp': -0.28, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 30, tzinfo=datetime.timezone.utc), 'atemp': -0.44, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 7, 45, tzinfo=datetime.timezone.utc), 'atemp': -0.44, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 8, 0, tzinfo=datetime.timezone.utc), 'atemp': -0.56, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 8, 15, tzinfo=datetime.timezone.utc), 'atemp': -0.78, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 8, 30, tzinfo=datetime.timezone.utc), 'atemp': -1.11, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 8, 45, tzinfo=datetime.timezone.utc), 'atemp': -1.0, 'pcpn': 0.0, 'relh': 97.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 9, 0, tzinfo=datetime.timezone.utc), 'atemp': -0.67, 'pcpn': 0.0, 'r ...
# 2023-10-23 09:53:55,291-32443-DEBUG-Starting new HTTPS connection (1): industrial.api.ubidots.com:443
# 2023-10-23 09:53:55,664-32443-DEBUG-https://industrial.api.ubidots.com:443 "GET /api/v2.0/devices/62c588591d84724fcb41b255/variables/?page_size=ALL HTTP/1.1" 200 None
# 2023-10-23 09:53:55,722-32443-DEBUG-Starting new HTTPS connection (1): industrial.api.ubidots.com:443
# 2023-10-23 09:53:56,411-32443-DEBUG-https://industrial.api.ubidots.com:443 "POST /api/v1.6/data/raw/series HTTP/1.1" 200 None
# 2023-10-23 09:53:56,415-32443-DEBUG-transformed_reading type <class 'list'>: []
# 2023-10-23 09:53:56,420-32443-DEBUG-Starting new HTTPS connection (1): zentracloud.com:443
# 2023-10-23 09:53:57,852-32443-DEBUG-https://zentracloud.com:443 "GET /api/v4/get_readings/?device_sn=z6-20553&start_date=2023-10-22+21%3A45%3A00&end_date=2023-10-23+09%3A45%3A00&page_num=1&per_page=1000 HTTP/1.1" 200 None
# 2023-10-23 09:53:57,970-32443-DEBUG-Zentra readings found
# 2023-10-23 09:53:57,971-32443-DEBUG-transformed_reading type <class 'dict_values'>: dict_values([{'data_datetime': datetime.datetime(2023, 10, 23, 13, 45, tzinfo=datetime.timezone.utc), 'atemp': 2.4, 'lws0': 5.0, 'pcpn': 0.034, 'relh': 100.1}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 40, tzinfo=datetime.timezone.utc), 'atemp': 2.3, 'lws0': 5.0, 'pcpn': 0.051, 'relh': 99.6}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 35, tzinfo=datetime.timezone.utc), 'atemp': 2.1, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 30, tzinfo=datetime.timezone.utc), 'atemp': 1.7, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.8}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 25, tzinfo=datetime.timezone.utc), 'atemp': 1.4, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 100.0}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 20, tzinfo=datetime.timezone.utc), 'atemp': 1.2, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.9}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 15, tzinfo=datetime.timezone.utc), 'atemp': 1.1, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.6}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 10, tzinfo=datetime.timezone.utc), 'atemp': 0.9, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.4}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 5, tzinfo=datetime.timezone.utc), 'atemp': 0.9, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 98.1}, {'data_datetime': datetime.datetime(2023, 10, 23, 13, 0, tzinfo=datetime.timezone.utc), 'atemp': 0.8, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 96.7}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 55, tzinfo=datetime.timezone.utc), 'atemp': 0.4, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 98.7}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 50, tzinfo=datetime.timezone.utc), 'atemp': 0.3, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 98.5}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 45, tzinfo=datetime.timezone.utc), 'atemp': 0.2, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.7}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 40, tzinfo=datetime.timezone.utc), 'atemp': 0.0, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.7}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 35, tzinfo=datetime.timezone.utc), 'atemp': 0.1, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 95.5}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 30, tzinfo=datetime.timezone.utc), 'atemp': 0.0, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 93.2}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 25, tzinfo=datetime.timezone.utc), 'atemp': -0.5, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 93.2}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 20, tzinfo=datetime.timezone.utc), 'atemp': -1.3, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 96.5}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 15, tzinfo=datetime.timezone.utc), 'atemp': -1.5, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.4}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 10, tzinfo=datetime.timezone.utc), 'atemp': -1.8, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.2}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 5, tzinfo=datetime.timezone.utc), 'atemp': -1.6, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.7}, {'data_datetime': datetime.datetime(2023, 10, 23, 12, 0, tzinfo=datetime.timezone.utc), 'atemp': -1.8, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 98.7}, {'data_datetime': datetime.datetime(2023, 10, 23, 11, 55, tzinfo=datetime.timezone.utc), 'atemp': -1.9, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 100.2}, {'data_datetime': datetime.datetime(2023, 10, 23, 11, 50, tzinfo=datetime.timezone.utc), 'atemp': -1.6, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 99.5}, {'data_datetime': datetime.datetime(2023, 10, 23, 11, 45, tzinfo=datetime.timezone.utc), 'atemp': -1.5, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 98.5}, {'data_datetime': datetime.datetime(2023, 10, 23, 11, 40, tzinfo=datetime.timezone.utc), 'atemp': -1.2, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 95.3}, {'data_datetime': datetime.datetime(2023, 10, 23, 11, 35, tzinfo=datetime.timezone.utc), 'atemp': -1.5, 'lws0': 5.0, 'pcpn': 0.0, 'relh': 97.0},  ...
# {'pagination': {'per_page': 1000, 'page_num': 1, 'next_url': 'https://zentracloud.com/api/v4/get_readings/?device_sn=z6-20553&start_date=2023-10-22+21%3A45%3A00&end_date=2023-10-23+09%3A45%3A00&page_num=2&per_page=1000', 'max_mrid': 56144, 'page_num_readings': 145, 'page_num_outputs': 3480, 'page_start_date': '2023-10-22 21:45:00-04:00', 'page_end_date': '2023-10-23 09:45:00-04:00', 'page_start_mrid': 56000, 'page_end_mrid': 56144}, 'data': {'Air Temperature': [{'metadata': {'device_sn': 'z6-20553', 'device_name': 'envwx-meter-fo2', 'port_number': 1, 'sensor_sn': 'ATM-410008286', 'sensor_name': 'ATMOS 41', 'units': ' °C'}, 'readings': [{'timestamp_utc': 1698068700, 'datetime': '2023-10-23 09:45:00-04:00', 'tz_offset': -14400, 'value': 2.4, 'precision': 1, 'mrid': 56144, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698068400, 'datetime': '2023-10-23 09:40:00-04:00', 'tz_offset': -14400, 'value': 2.3, 'precision': 1, 'mrid': 56143, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698068100, 'datetime': '2023-10-23 09:35:00-04:00', 'tz_offset': -14400, 'value': 2.1, 'precision': 1, 'mrid': 56142, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698067800, 'datetime': '2023-10-23 09:30:00-04:00', 'tz_offset': -14400, 'value': 1.7, 'precision': 1, 'mrid': 56141, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698067500, 'datetime': '2023-10-23 09:25:00-04:00', 'tz_offset': -14400, 'value': 1.4, 'precision': 1, 'mrid': 56140, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698067200, 'datetime': '2023-10-23 09:20:00-04:00', 'tz_offset': -14400, 'value': 1.2, 'precision': 1, 'mrid': 56139, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698066900, 'datetime': '2023-10-23 09:15:00-04:00', 'tz_offset': -14400, 'value': 1.1, 'precision': 1, 'mrid': 56138, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698066600, 'datetime': '2023-10-23 09:10:00-04:00', 'tz_offset': -14400, 'value': 0.9, 'precision': 1, 'mrid': 56137, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698066300, 'datetime': '2023-10-23 09:05:00-04:00', 'tz_offset': -14400, 'value': 0.9, 'precision': 1, 'mrid': 56136, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698066000, 'datetime': '2023-10-23 09:00:00-04:00', 'tz_offset': -14400, 'value': 0.8, 'precision': 1, 'mrid': 56135, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698065700, 'datetime': '2023-10-23 08:55:00-04:00', 'tz_offset': -14400, 'value': 0.4, 'precision': 1, 'mrid': 56134, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698065400, 'datetime': '2023-10-23 08:50:00-04:00', 'tz_offset': -14400, 'value': 0.3, 'precision': 1, 'mrid': 56133, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698065100, 'datetime': '2023-10-23 08:45:00-04:00', 'tz_offset': -14400, 'value': 0.2, 'precision': 1, 'mrid': 56132, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698064800, 'datetime': '2023-10-23 08:40:00-04:00', 'tz_offset': -14400, 'value': 0.0, 'precision': 1, 'mrid': 56131, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698064500, 'datetime': '2023-10-23 08:35:00-04:00', 'tz_offset': -14400, 'value': 0.1, 'precision': 1, 'mrid': 56130, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698064200, 'datetime': '2023-10-23 08:30:00-04:00', 'tz_offset': -14400, 'value': 0.0, 'precision': 1, 'mrid': 56129, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698063900, 'datetime': '2023-10-23 08:25:00-04:00', 'tz_offset': -14400, 'value': -0.5, 'precision': 1, 'mrid': 56128, 'error_flag': False, 'error_description': None}, {'timestamp_utc': 1698063600, 'datetime': '2023-10-23 08:20:00-04:00', 'tz_offset': -14400, 'value': -1.3, 'precision': 1, 'mrid': 56127, 'error_flag': False, 'error_description': None}, {'time ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/billspat/Code/enviroweather-project/ewx_pws/docs/database.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/billspat/Code/enviroweather-project/ewx_pws/docs/database.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> raw_records, readings_records = collector.collect_readings(interval)
#       <a href='vscode-notebook-cell:/Users/billspat/Code/enviroweather-project/ewx_pws/docs/database.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> readings_df = pd.DataFrame(readings_records)
#       <a href='vscode-notebook-cell:/Users/billspat/Code/enviroweather-project/ewx_pws/docs/database.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> display(readings_df)
#
# ValueError: too many values to unpack (expected 2)

# %%
from ewx_pws.weather_store import WeatherStore
dbfile = '../../tmp_ewx_pws.sqlite3'
weatherstore = WeatherStore(dbfile)
weatherstore.engine
weatherstore.connection

# %%
from sqlalchemy import inspect, text
insp = inspect(weatherstore.engine)
insp.has_table('stations')
# Out:
# True

# %%
tablename = 'stations'
import json
from datetime import datetime

from ewx_pws.ewx_pws import STATION_CLASS_TYPES as station_class_types
result = weatherstore.connection.execute(text(f"select * from {tablename}"))
stations = {}
for row in result:
    station_config = dict(zip(row._mapping.keys(), row._mapping.values()))
    if 'index' in station_config: del station_config['index'] 
    station_config.update(json.loads(station_config['station_config']))
    print(station_config)
    station_type = station_config['station_type']
    station_id = station_config['station_id']
    station_config['install_date'] = datetime.fromisoformat(station_config['install_date'])
    stations[station_id] = station_class_types[station_type].init_from_dict(station_config)
# Out:
# {'station_id': 'EWX-METER-FO', 'station_type': 'ZENTRA', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"sn":"z6-12564","token":"5b8f637a718b9e3ad6e31eec81f0b51d91ac38bd"}', 'sn': 'z6-12564', 'token': '5b8f637a718b9e3ad6e31eec81f0b51d91ac38bd'}
# {'station_id': 'EWXDAVIS01', 'station_type': 'DAVIS', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"sn":"117005","apikey":"aoqdcbirudd1sarq6erfj6tgtw67sbvo","apisec":"elvr77yhdx3p0286cwnnqqstdwqg8zxf"}', 'sn': '117005', 'apikey': 'aoqdcbirudd1sarq6erfj6tgtw67sbvo', 'apisec': 'elvr77yhdx3p0286cwnnqqstdwqg8zxf'}
# {'station_id': 'EWXSPECTRUM01', 'station_type': 'SPECTRUM', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"sn":"50400123","apikey":"11a5c3a939856b08677b7a072f8e6865"}', 'sn': '50400123', 'apikey': '11a5c3a939856b08677b7a072f8e6865'}
# {'station_id': 'EWXONSET01', 'station_type': 'ONSET', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"sn":"21092695","client_id":"Enviroweather_WS","client_secret":"75d2b7f58f5d0cac699f5b9616318be268057de6","ret_form":"JSON","user_id":"12848","sensor_sn":{"atemp":"21079936-1","pcpn":"21085496-1","relh":"21079936-2"}}', 'sn': '21092695', 'client_id': 'Enviroweather_WS', 'client_secret': '75d2b7f58f5d0cac699f5b9616318be268057de6', 'ret_form': 'JSON', 'user_id': '12848', 'sensor_sn': {'atemp': '21079936-1', 'pcpn': '21085496-1', 'relh': '21079936-2'}}
# {'station_id': 'EWXRAINWISE01', 'station_type': 'RAINWISE', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"sid":"66af9e2c2d360730fc4559aad6472056","pid":"66af9e2c2d360730fc4559aad6472056","ret_form":"json","mac":"200000000500","username":"200000000500"}', 'sid': '66af9e2c2d360730fc4559aad6472056', 'pid': '66af9e2c2d360730fc4559aad6472056', 'ret_form': 'json', 'mac': '200000000500', 'username': '200000000500'}
# {'station_id': 'EWXLOCOMOS06', 'station_type': 'LOCOMOS', 'install_date': '2023-05-01', 'tz': 'ET', 'station_config': '{"token":"BBFF-MMZJs422YNyUyA3sh3ePXKAnMZp7yz","id":"62c588591d84724fcb41b255"}', 'token': 'BBFF-MMZJs422YNyUyA3sh3ePXKAnMZp7yz', 'id': '62c588591d84724fcb41b255'}
# {'station_id': 'EWX-METER-FO2', 'station_type': 'ZENTRA', 'install_date': '2023-09-10', 'tz': 'ET', 'station_config': '{"sn":"z6-20553","token":"12cc21d9f697e478885cca9b65307d27872dfb18"}', 'sn': 'z6-20553', 'token': '12cc21d9f697e478885cca9b65307d27872dfb18'}

# %%
# add stations

station_ids = [station.id for station in collector.stations]
print(station_ids)
stations = dict(zip(station_ids, collector.stations))

# %%
weatherstore.stations = None

# %%
def dict_factory(cursor, row):
    d = {}
    for idx, col in enumerate(cursor.description):
        d[col[0]] = row[idx]
    return d


# weatherstore.conn.row_factory = sqlite3.Row 
weatherstore.conn.row_factory = dict_factory
cursor = weatherstore.conn.cursor()

cursor.execute("PRAGMA table_list;")
pprint(cursor.fetchall())
# for row in cursor.fetchall():
#    for k in row.keys():
#        print()

# %%
def dict_factory(cursor, row):
    d = {}
    for idx, col in enumerate(cursor.description):
        d[col[0]] = row[idx]
    return d

def list_tables(conn):
    cursor = conn.cursor()
    cursor.execute("PRAGMA table_list;")
    table_list =  cursor.fetchall()
    cursor.close()
    return(table_list)

def table_columns(conn, tablename):
    cursor = conn.cursor()
    columnsQuery = ("PRAGMA table_info(%s)" % (tablename))
    cursor.execute(columnsQuery)
    columns = [column for column in cursor.fetchall()]
    cursor.close()
    return(columns)

print(list_tables(weatherstore.conn))

# %%
list_tables(weatherstore.conn)

# %%
import pandas as pd
stationsdf = pd.read_csv(station_config_file,header=0,quotechar="'")
# stations = weatherstore.create_stations_table_from_file(station_config_file)
display(stationsdf)

# %%
nrows = stationsdf.to_sql(name=weatherstore.stations_table, con= weatherstore.conn, if_exists='replace')
nrows

# %%
from sqlalchemy import engine,create_engine
from os import getenv
from dotenv import load_dotenv
load_dotenv('../.env')

PWSDBURI=getenv('PWSDBURI')
print(PWSDBURI)
if not PWSDBURI:
    raise ValueError("PWSDBURI is not set")
    
engine = create_engine(PWSDBURI)

# %%
from sqlalchemy import MetaData, inspect


# method A
inspector = inspect(engine)
for table_name in inspector.get_table_names():
   print(table_name)
   print('-----')
   for column in inspector.get_columns(table_name):
       print("Column: %s" % column['name'])

# method B, for postgresql
schema="public"
with engine.connect() as conn:
        meta = MetaData(conn, schema=schema)
        meta.reflect(views=True)
        tables = (list(meta.tables.keys()))

print(tables)

# %%
import pandas as pd

with engine.connect() as conn, conn.begin():
    station_configs = pd.read_sql_table(weatherstore.stations_table, conn)

print(station_configs.to_string())

# %%
sql = f"select * from {weatherstore.stations_table}"
station_configs = pandas.read_sql(sql, con=weatherstore.conn)
display(station_configs)
